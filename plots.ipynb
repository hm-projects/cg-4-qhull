# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
POINTS = "Points (X)"
DIMENSION = "Dimension (Y)"
TIMING = "Timing (s)"
DISTANCE_TEST = "Distance tests for qhull"

# %%
sphere = pd.read_csv("sphere.csv")
sphere = sphere.set_index(POINTS)
_ = sphere.plot(
    subplots=True, title="Sphere QHULL Distance Tests and Timing (s) Change by Dimension and Number of Points")

# %%
spiral = pd.read_csv("spiral.csv")
spiral = spiral.set_index(POINTS)
_ = spiral.plot(subplots=True,
                title="Spiral QHULL Distance Tests and Timing (s) Change by Dimension and Number of Points")

# %%
cube = pd.read_csv("cube.csv")

c_timing = cube.drop(DISTANCE_TEST, axis=1)
c_distance = cube.drop(TIMING, axis=1)

_ = c_distance.groupby([POINTS, DIMENSION]).first().unstack().plot(
    title="Cube QHULL Distance Tests Change by Dimension and Number of Points")
_ = c_timing.groupby([POINTS, DIMENSION]).first().unstack().plot(
    title="Cube QHULL Timing (s) Change by Dimension and Number of Points")

# %%
c_timing
# Out:
#     Dimension (Y)  Points (X)  Timing (s)
# 0               2          10       0.000
# 1               2         100       0.000
# 2               2        1000       0.000
# 3               2       10000       0.001
# 4               2      100000       0.008
# 5               2     1000000       0.078
# 6               2    10000000       0.774
# 7               3          10       0.000
# 8               3         100       0.000
# 9               3        1000       0.000
# 10              3       10000       0.003
# 11              3      100000       0.017
# 12              3     1000000       0.178
# 13              3    10000000       1.566
# 14              4          10       0.000
# 15              4         100       0.000
# 16              4        1000       0.002
# 17              4       10000       0.009
# 18              4      100000       0.051
# 19              4     1000000       1.035
# 20              4    10000000       4.749
# ...

# %%
c_distance.groupby([POINTS, DIMENSION]).first().unstack()
# Out:
#               Distance tests for qhull
# Dimension (Y)                        2            3            4
# Points (X)
# 10                                51.0         53.0         65.0  \
# 100                              648.0       1163.0       3397.0
# 1000                            6596.0      12879.0      38085.0
# 10000                          65961.0     126745.0     348774.0
# 100000                        657162.0    1237314.0    3428341.0
# 1000000                      6440706.0   11157377.0   69925223.0
# 10000000                    62312449.0  114508002.0  307025045.0
#
#
# Dimension (Y)             5             6             7           8
# Points (X)
# 10             5.300000e+01  5.500000e+01  2.300000e+01         9.0
# 100            9.625000e+03  2.653500e+04  9.012900e+04    289174.0
# 1000           2.954000e+04  7.779570e+05  3.509740e+06  18205216.0
# 10000          1.843925e+06  1.365756e+07  8.392418e+07         NaN
# ...
